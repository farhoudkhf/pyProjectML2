# %%
# !pip install torch torchvision torchaudio

# %%
# !pip install torch

# %%
conda install pytorch torchvision torchaudio cpuonly -c pytorch
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'install pytorch torchvision torchaudio cpuonly -c pytorch')
#
# File ~/Library/Python/3.12/lib/python/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available()) # Check GPU availability if installed with GPU support
# Out:
# 2.5.1
# False

# %%
import sys
print("--- Notebook sys.executable ---")
print(sys.executable)
print("\n--- Notebook sys.path ---")
print(sys.path)
print("\n--- Checking if torch is available in this environment ---")
try:
    import torch
    print("Torch is found in this environment's sys.path, but import still failed?")
except ModuleNotFoundError:
    print("Torch is NOT found in this environment's sys.path.")
except Exception as e:
    print(f"An unexpected error occurred when checking for torch: {e}")

print("\n--- Listing packages in this environment (attempting via !pip) ---")
# Note: This might not work perfectly in all environments, but is worth trying
try:
    get_ipython().system('pip list')
except NameError:
    print("Running outside IPython/Jupyter environment.")
except Exception as e:
    print(f"Could not run !pip list: {e}")
# Out:
# --- Notebook sys.executable ---
# /usr/local/bin/python3
#
# --- Notebook sys.path ---
# ['/Library/Frameworks/Python.framework/Versions/3.12/lib/python312.zip', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/lib-dynload', '', '/Users/farhoudkhoshnoud/Library/Python/3.12/lib/python/site-packages', '/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages']
#
# --- Checking if torch is available in this environment ---
# Torch is NOT found in this environment's sys.path.
#
# --- Listing packages in this environment (attempting via !pip) ---
# Package                           Version
# --------------------------------- ------------
# aext-assistant                    4.0.15
# aext-assistant-server             4.0.15
# aext-core                         4.0.15
# aext-core-server                  4.0.15
# aext-panels                       4.0.15
# ...
